# %%
import pandas as pd

# %%
df = pd.read_csv("./dataset/analysis_prepro/clothes1.txt", delimiter=":")

# %%
df
# Out:
#      size  price     brand
# 0   small     10       cob
# 1  medium     12     peter
# 2   large     15     monte
# 3   small     11     monte
# 4  medium     10  cantabil
# 5  medium     10       cob

# %%
df = pd.read_csv("./dataset/analysis_prepro/clothes2.txt", delimiter="\\")

# %%
df
# Out:
#      size\tprice\tbrand
# 0        small\t10\tcob
# 1     medium\t12\tpeter
# 2      large\t15\tmonte
# 3      small\t11\tmonte
# 4  medium\t10\tcantabil
# 5     medium\t10\tmonte

# %%
df = pd.read_csv("./dataset/analysis_prepro/clothes3.csv", names=['a', 'b', 'c'])

# %%
df
# Out:
#         a      b         c
# 0    size  price     brand
# 1   small     10       cob
# 2  medium     12     peter
# 3   large     15     monte
# 4   small     11     monte
# 5  medium     10  cantabil
# 6  medium     10     monte

# %%
df = pd.read_csv("./dataset/analysis_prepro/clothes3.csv", names=['a', 'b', 'c'], nrows=3)

# %%
df
# Out:
#         a      b      c
# 0    size  price  brand
# 1   small     10    cob
# 2  medium     12  peter

# %%
pd.read_csv("./dataset/analysis_prepro/clothes3.csv", names=['a', 'b', 'c'], skiprows=2)
# Out:
#         a   b         c
# 0  medium  12     peter
# 1   large  15     monte
# 2   small  11     monte
# 3  medium  10  cantabil
# 4  medium  10     monte

# %%
pd.read_csv("./dataset/analysis_prepro/clothes3.csv", usecols=['size'])
# Out:
#      size
# 0   small
# 1  medium
# 2   large
# 3   small
# 4  medium
# 5  medium

# %%
df = pd.read_excel("./dataset/analysis_prepro/movies_sheets.xls")

# %%
df.shape
# Out:
# (1338, 25)

# %%
df.head(2)
# Out:
#                                                Title  Year           Category  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916  Drama|History|War
# 1                    Over the Hill to the Poorhouse   1920        Crime|Drama
#
#   Language Country Content Rating  Duration  Aspect Ratio    Budget  \
# 0      NaN     USA      Not Rated       123          1.33  385907.0
# 1      NaN     USA            NaN       110          1.33  100000.0
#
#    Gross Earnings  ... Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 0             NaN  ...                      436                       22
# 1       3000000.0  ...                        2                        2
#
#   Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 0                      9.0                         481
# 1                      0.0                           4
#
#    Facebook likes - Movie  Facenumber in posters  User Votes  \
# 0                     691                      1       10718
# ...

# %%
df.tail()
# Out:
#                                Title  Year                      Category  \
# 1333               Twin Falls Idaho   1999                         Drama
# 1334  Universal Soldier: The Return   1999                 Action|Sci-Fi
# 1335                  Varsity Blues   1999    Comedy|Drama|Romance|Sport
# 1336                 Wild Wild West   1999  Action|Comedy|Sci-Fi|Western
# 1337                 Wing Commander   1999       Action|Adventure|Sci-Fi
#
#      Language Country Content Rating  Duration  Aspect Ratio       Budget  \
# 1333  English     USA              R       111          1.85     500000.0
# 1334  English     USA              R        83          1.85   24000000.0
# 1335  English     USA              R       106          1.85   16000000.0
# 1336  English     USA          PG-13       106          1.85  170000000.0
# 1337  English     USA          PG-13       100          2.35   30000000.0
#
#       Gross Earnings  ... Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# ...

# %%
df.tail(3)
# Out:
#                 Title  Year                      Category Language Country  \
# 1335   Varsity Blues   1999    Comedy|Drama|Romance|Sport  English     USA
# 1336  Wild Wild West   1999  Action|Comedy|Sci-Fi|Western  English     USA
# 1337  Wing Commander   1999       Action|Adventure|Sci-Fi  English     USA
#
#      Content Rating  Duration  Aspect Ratio       Budget  Gross Earnings  ...  \
# 1335              R       106          1.85   16000000.0      52885587.0  ...
# 1336          PG-13       106          1.85  170000000.0     113745408.0  ...
# 1337          PG-13       100          2.35   30000000.0      11576087.0  ...
#
#      Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 1335                    23000                      255
# 1336                    10000                     4000
# 1337                      811                      586
#
#      Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 1335                     35.0                       23369
# ...

# %%
df.tail(2)
# Out:
#                 Title  Year                      Category Language Country  \
# 1336  Wild Wild West   1999  Action|Comedy|Sci-Fi|Western  English     USA
# 1337  Wing Commander   1999       Action|Adventure|Sci-Fi  English     USA
#
#      Content Rating  Duration  Aspect Ratio       Budget  Gross Earnings  ...  \
# 1336          PG-13       106          1.85  170000000.0     113745408.0  ...
# 1337          PG-13       100          2.35   30000000.0      11576087.0  ...
#
#      Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 1336                    10000                     4000
# 1337                      811                      586
#
#      Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 1336                    582.0                       15870
# 1337                    362.0                        2497
#
#       Facebook likes - Movie  Facenumber in posters  User Votes  \
# 1336                       0                      2      129601
# ...

# %%
data1 = pd.read_csv('./dataset/analysis_prepro/clothes.txt')
data2 = pd.read_csv('./dataset/analysis_prepro/clothes3.csv')

# %%
data1.shape
# Out:
# (6, 3)

# %%
data2.shape
# Out:
# (6, 3)

# %%
data3 = data1.append(data2, ignore_index=True)

# %%
data3.shape
# Out:
# (12, 3)

# %%
data3
# Out:
#       size  price     brand
# 0    small     10       cob
# 1   medium     12     peter
# 2    large     15     monte
# 3    small     11     monte
# 4   medium     10  cantabil
# 5   medium     10       cob
# 6    small     10       cob
# 7   medium     12     peter
# 8    large     15     monte
# 9    small     11     monte
# 10  medium     10  cantabil
# 11  medium     10     monte

# %%
df1 = pd.read_excel("./dataset/analysis_prepro/movies_sheets.xls", sheet_name=0)

# %%
df2 = pd.read_excel("./dataset/analysis_prepro/movies_sheets.xls", sheet_name=1)

# %%
df3 = pd.read_excel("./dataset/analysis_prepro/movies_sheets.xls", sheet_name=2)

# %%
df4 = df1.append([df2, df3], ignore_index=True)

# %%
df4.shape
# Out:
# (5042, 25)

# %%
df4.to_excel("movies_sheet_chandan.xls")

# %%
df4.to_csv("movies_sheet_chandan.text", index=False, index_label=False)

# %%
d = pd.read_json('./dataset/analysis_prepro/students.json')

# %%
d.to_json("students.json")

# %%
import psycopg2 as pg
import pandas.io.sql as psql
con = pg.connect("host=localhost dbname=kinder user=chandan password=08/08/2019")
product = psql.read_sql('SELECT * FROM product_product', con)

# %%
product
# Out:
#    id message_main_attachment_id default_code  active  product_tmpl_id  \
# 0   1                       None         INRF    True                1
#
#   barcode volume weight  create_uid                create_date  write_uid  \
# 0    None   None   None           2 2020-01-31 12:13:26.339979          2
#
#                   write_date
# 0 2020-01-31 12:13:26.339979

# %%
titanic = pd.read_csv("./dataset/analysis_prepro/titanic.csv")
df.shape
# Out:
# (1338, 25)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['Pclass'].max()
# Out:
# 3

# %%
survived = titanic[titanic['Survived'] == 1]

# %%
survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
titanic[titanic.Survived == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
titanic[titanic.Survived == 1].shape
# Out:
# (342, 12)

# %%
titanic[titanic.Survived == 0].shape
# Out:
# (549, 12)

# %%
titanic.Survived.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.Pclass.unique()
# Out:
# array([3, 1, 2])

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic[titanic['Survived'] == 1].gender.value_counts()
# Out:
# female    233
# male      109
# Name: gender, dtype: int64

# %%
df = pd.read_csv('./dataset/analysis_prepro/movies.csv')
df.shape
# Out:
# (979, 6)

# %%
df.head()
# Out:
#    star_rating                     title content_rating category  duration  \
# 0          9.3  The Shawshank Redemption              R    Crime       142
# 1          9.2             The Godfather              R    Crime       175
# 2          9.1    The Godfather: Part II              R    Crime       200
# 3          9.0           The Dark Knight          PG-13   Action       152
# 4          8.9              Pulp Fiction              R    Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df['category'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: category, dtype: int64

# %%
df.sort_values(by=['duration', 'star_rating'], ascending=False).head()
# Out:
#      star_rating                              title content_rating   category  \
# 476          7.8                             Hamlet          PG-13      Drama
# 157          8.2                 Gone with the Wind              G      Drama
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
#
#      duration                                        actors_list
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 445       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...

# %%
df.sort_index(axis=1).head()
# Out:
#                                          actors_list category content_rating  \
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...    Crime              R
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']    Crime              R
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...    Crime              R
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...   Action          PG-13
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....    Crime              R
#
#    duration  star_rating                     title
# 0       142          9.3  The Shawshank Redemption
# 1       175          9.2             The Godfather
# 2       200          9.1    The Godfather: Part II
# 3       152          9.0           The Dark Knight
# 4       154          8.9              Pulp Fiction

# %%
df.sort_index().head()
# Out:
#    star_rating                     title content_rating category  duration  \
# 0          9.3  The Shawshank Redemption              R    Crime       142
# 1          9.2             The Godfather              R    Crime       175
# 2          9.1    The Godfather: Part II              R    Crime       200
# 3          9.0           The Dark Knight          PG-13   Action       152
# 4          8.9              Pulp Fiction              R    Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df[df['title'].str.startswith('The')]['star_rating'].mean()
# Out:
# 7.916143497757833

# %%
df[df['title'].str.startswith('The')]['duration'].mean()
# Out:
# 122.80717488789237

# %%
df[df['actors_list'].str.contains('amir khan', case=False)].title
# Out:
# 47                      Taare Zameen Par
# 60                              3 Idiots
# 72                       Rang De Basanti
# 109                       Dil Chahta Hai
# 142    Lagaan: Once Upon a Time in India
# Name: title, dtype: object

# %%
df[(df['duration']>50) & (df['duration']<70)].shape
# Out:
# (6, 6)

# %%
df[df.duration.isin(range(50,70))].shape
# Out:
# (6, 6)

# %%
df[['duration', 'star_rating']]
# Out:
#      duration  star_rating
# 0         142          9.3
# 1         175          9.2
# 2         200          9.1
# 3         152          9.0
# 4         154          8.9
# 5          96          8.9
# 6         161          8.9
# 7         201          8.9
# 8         195          8.9
# 9         139          8.9
# 10        178          8.8
# 11        148          8.8
# 12        124          8.8
# 13        142          8.8
# 14        179          8.8
# 15        169          8.7
# 16        133          8.7
# 17        207          8.7
# 18        146          8.7
# 19        121          8.7
# 20        136          8.7
# 21        130          8.7
# 22        130          8.7
# 23        106          8.7
# 24        127          8.7
# 25        116          8.6
# 26        175          8.6
# 27        118          8.6
# 28        110          8.6
# 29         87          8.6
# ..        ...          ...
# 949       103          7.4
# 950       108          7.4
# ...

# %%
df = pd.read_csv('./dataset/analysis_prepro/clothes.txt')

# %%
df.brand
# Out:
# 0         cob
# 1       peter
# 2       monte
# 3       monte
# 4    cantabil
# 5         cob
# Name: brand, dtype: object

# %%
df.size
# Out:
# 18

# %%
df1 = df.rename({'price':'item price'}, axis=1)

# %%
df1['item price']
# Out:
# 0    10
# 1    12
# 2    15
# 3    11
# 4    10
# 5    10
# Name: item price, dtype: int64

# %%
df1[['brand', 'size']]
# Out:
#       brand    size
# 0       cob   small
# 1     peter  medium
# 2     monte   large
# 3     monte   small
# 4  cantabil  medium
# 5       cob  medium

# %%
df[2:3]
# Out:
#     size  price  brand
# 2  large     15  monte

# %% [markdown]
# >Row index

# %%
df[2:4]
# Out:
#     size  price  brand
# 2  large     15  monte
# 3  small     11  monte

# %% [markdown]
# ### particular value selection

# %%
df1.at[2,'item price'] # row with column name
# Out:
# 15

# %%
df1.iat[2,1] # index wise
# Out:
# 15

# %%
df1.rename({0:'a', 1:'b', 2:'c'}, axis=0, inplace=True)

# %%
df1.at['a', 'brand']
# Out:
# 'cob'

# %%
df1.iat[0,2]
# Out:
# 'cob'

# %%
df = pd.read_csv('./dataset/analysis_prepro/movies.csv')

# %%
df.loc[1:3] # at loc function both index is included
# Out:
#    star_rating                   title content_rating category  duration  \
# 1          9.2           The Godfather              R    Crime       175
# 2          9.1  The Godfather: Part II              R    Crime       200
# 3          9.0         The Dark Knight          PG-13   Action       152
#
#                                          actors_list
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
df.loc[1:4, ('duration', 'title')]
# Out:
#    duration                   title
# 1       175           The Godfather
# 2       200  The Godfather: Part II
# 3       152         The Dark Knight
# 4       154            Pulp Fiction

# %%
df.iloc[1:3, -3:-6:-2] # row slicing and column slicing with step
# Out:
#   category                   title
# 1    Crime           The Godfather
# 2    Crime  The Godfather: Part II

# %%
df.head()
# Out:
#    star_rating                     title content_rating category  duration  \
# 0          9.3  The Shawshank Redemption              R    Crime       142
# 1          9.2             The Godfather              R    Crime       175
# 2          9.1    The Godfather: Part II              R    Crime       200
# 3          9.0           The Dark Knight          PG-13   Action       152
# 4          8.9              Pulp Fiction              R    Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df = pd.read_csv('./dataset/analysis_prepro/titanic.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df1 = df.iloc[:60, 0:9]
df1.shape
# Out:
# (60, 9)

# %%
df2 = df.iloc[60:100, 0:9]
df2.shape
# Out:
# (40, 9)

# %%
df3 = df.iloc[0:60, 9:]
df3
# Out:
#         Fare        Cabin Embarked
# 0     7.2500          NaN        S
# 1    71.2833          C85        C
# 2     7.9250          NaN        S
# 3    53.1000         C123        S
# 4     8.0500          NaN        S
# 5     8.4583          NaN        Q
# 6    51.8625          E46        S
# 7    21.0750          NaN        S
# 8    11.1333          NaN        S
# 9    30.0708          NaN        C
# 10   16.7000           G6        S
# 11   26.5500         C103        S
# 12    8.0500          NaN        S
# 13   31.2750          NaN        S
# 14    7.8542          NaN        S
# 15   16.0000          NaN        S
# 16   29.1250          NaN        Q
# 17   13.0000          NaN        S
# 18   18.0000          NaN        S
# 19    7.2250          NaN        C
# 20   26.0000          NaN        S
# 21   13.0000          D56        S
# 22    8.0292          NaN        Q
# 23   35.5000           A6        S
# 24   21.0750          NaN        S
# 25   31.3875          NaN        S
# ...

# %%
df4 = df.iloc[60:100, 9:10]
df4
# Out:
#         Fare
# 60    7.2292
# 61   80.0000
# 62   83.4750
# 63   27.9000
# 64   27.7208
# 65   15.2458
# 66   10.5000
# 67    8.1583
# 68    7.9250
# 69    8.6625
# 70   10.5000
# 71   46.9000
# 72   73.5000
# 73   14.4542
# 74   56.4958
# 75    7.6500
# 76    7.8958
# 77    8.0500
# 78   29.0000
# 79   12.4750
# 80    9.0000
# 81    9.5000
# 82    7.7875
# 83   47.1000
# 84   10.5000
# 85   15.8500
# 86   34.3750
# 87    8.0500
# 88  263.0000
# 89    8.0500
# 90    8.0500
# 91    7.8542
# 92   61.1750
# 93   20.5750
# 94    7.2500
# 95    8.0500
# 96   34.6542
# 97   63.3583
# 98   23.0000
# 99   26.0000

# %%
df5 = df.iloc[60:100, [9]]
df5
# Out:
#         Fare
# 60    7.2292
# 61   80.0000
# 62   83.4750
# 63   27.9000
# 64   27.7208
# 65   15.2458
# 66   10.5000
# 67    8.1583
# 68    7.9250
# 69    8.6625
# 70   10.5000
# 71   46.9000
# 72   73.5000
# 73   14.4542
# 74   56.4958
# 75    7.6500
# 76    7.8958
# 77    8.0500
# 78   29.0000
# 79   12.4750
# 80    9.0000
# 81    9.5000
# 82    7.7875
# 83   47.1000
# 84   10.5000
# 85   15.8500
# 86   34.3750
# 87    8.0500
# 88  263.0000
# 89    8.0500
# 90    8.0500
# 91    7.8542
# 92   61.1750
# 93   20.5750
# 94    7.2500
# 95    8.0500
# 96   34.6542
# 97   63.3583
# 98   23.0000
# 99   26.0000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
t = df.drop("gender", axis=1)
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
for i in df:
    print(i)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %%
df.pop('Survived')
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# ###  EDA
# >Exploratory Data Analysis

# %%
tips = pd.read_csv('./dataset/analysis_prepro/tips.csv')
tips
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# gender        244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe(include='all')
# Out:
#         total_bill         tip gender smoker  day    time        size
# count   244.000000  244.000000    244    244  244     244  244.000000
# unique         NaN         NaN      2      2    4       2         NaN
# top            NaN         NaN   Male     No  Sat  Dinner         NaN
# freq           NaN         NaN    157    151   87     176         NaN
# mean     19.785943    2.998279    NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638    NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000    NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000    NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000    NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500    NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000    NaN    NaN  NaN     NaN    6.000000

# %%
tips.groupby('gender').max()
# Out:
#         total_bill   tip smoker   day   time  size
# gender
# Female       44.30   6.5    Yes  Thur  Lunch     6
# Male         50.81  10.0    Yes  Thur  Lunch     6

# %%
tips.groupby('gender').mean()
# Out:
#         total_bill       tip      size
# gender
# Female   18.056897  2.833448  2.459770
# Male     20.744076  3.089618  2.630573

# %%
tips.groupby('day').max()
# Out:
#       total_bill    tip gender smoker    time  size
# day
# Fri        40.17   4.73   Male    Yes   Lunch     4
# Sat        50.81  10.00   Male    Yes  Dinner     5
# Sun        48.17   6.50   Male    Yes  Dinner     6
# Thur       43.11   6.70   Male    Yes   Lunch     6
