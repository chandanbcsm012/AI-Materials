# %% [markdown]
# # Pandas (Panel data)
#
# 1. Pandas is an open source library builtin on top of NumPy.
# 2. It allows for falst analysis, data cleaniing and prepration
# 3. It excelenc in proformance and productivity.
# 4. It also has builtin visualization features.
# 5. It can work with data from a wide variety of sources.
#
#
#     1. Pandas is a python package,first introduced in Jan 2008.
#     2. it represents multi-dim structure data with labels.
#     3. it is used in data analysis and data preprocessing(manipulation).
#     4. it is not the part of default python and we need to download it
#     pip insatll pandas
#
# Variables:
# ---------
#
#     df.shape
#     df.columns
#     df.size
#     df.dtypes
#
# Methods for Analysis:
# ---------------------
#     df.head()
#     df.tail()
#     df.describe()
#     df.info()
#     df.col_label.unique()
#     df.col_label.value_counts()
#     df.col_label.isnull()
#     df.col_label.isnull().sum()
#     df.isnull()
#     df.isnull().sum()
#     df.sort_values()
#     df.fillna()
#     df.ffill()
#     df.bfill()
#     df.replace()
#     df.dropna()
#     df.drop_duplicates()
#     df.groupby()
#
# Commonly used 2 types(objects) in pandas:
# --------------------------------------
#     1. Series
#     2. DataFrame
#
#             DataFrame
#             ---------
#    1. Generally represents 2 dim array in tabular form.
#    2. we may provide label row & column indexing
#    3. it is mutable in size
#
#
# 1. Creation of DataFrame
#       1. from list of lists
#       2. from list of dicts
#       3. from dict of lists
#       4. from tuple of list (loop with append)
#       5. from other DataFrame
#       6. empty DataFrame
#       7. from excel file
#       8. from database cursor
#       9. from json file
#
# 2. Iterating DataFrame:
#    1. iteritems()
#    2. iterrows()
#    3. itertuples()
#
# 3.Adding/Deleting/Updating/Renaming/ReOdering Columns & Rows.
#
# 4.Setting value to a cell
#
# 5.loc & iloc
#
# 6.sorting(asc/desc) df by column
#
# 7.apply method
#
# 8.find missing values in all columns/specific column
#
# 9.filtering data from DataFrame
#
# 10.count(),value_count(),isin(),unique(),nunique(),mean(),head(),dtypes,
#
# 11.boolean indexing in DataFrame
#
# 12.date/time handling

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Panel Data :**  data of an org or individual based on time
#
# structured data

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame([['Sonu', 20, 2000], ['monu', 21, 19000]])
df
# Out:
#       0   1      2
# 0  Sonu  20   2000
# 1  monu  21  19000

# %% [markdown]
# labels ----> column name
#
# index -----> row name

# %%
df = pd.DataFrame([['Sonu', 20, 2000], ['monu', 21, 19000]], index=["r1", "r2"])
df
# Out:
#        0   1      2
# r1  Sonu  20   2000
# r2  monu  21  19000

# %%
df = pd.DataFrame([['Sonu', 20, 2000], ['monu', 21, 19000]], index=["r1", "r2"], columns=["a1", 'a2', 'a3'])
df
# Out:
#       a1  a2     a3
# r1  Sonu  20   2000
# r2  monu  21  19000

# %%
df = pd.DataFrame({'empid':[10, 20, 30], 'salary':[10000, 19000, 20000]})
df
# Out:
#    empid  salary
# 0     10   10000
# 1     20   19000
# 2     30   20000

# %% [markdown]
# datafrme each column is series
#
# series is represent in 1d array

# %%
empid = df['empid']
empid
# Out:
# 0    10
# 1    20
# 2    30
# Name: empid, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(empid)
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#    empid  salary
# 0     10   10000
# 1     20   19000
# 2     30   20000

# %%
df['name'] = ['Sonu', 'Monu', 'Tonu']
df
# Out:
#    empid  salary  name
# 0     10   10000  Sonu
# 1     20   19000  Monu
# 2     30   20000  Tonu

# %%
df['area']=pd.Series(['up', 'delhi', 'HP'])
df
# Out:
#    empid  salary  name   area
# 0     10   10000  Sonu     up
# 1     20   19000  Monu  delhi
# 2     30   20000  Tonu     HP

# %%
df[0:1]
# Out:
#    empid  salary  name area
# 0     10   10000  Sonu   up

# %%
df.insert(1, 'poc', [10, 20, 30])
df
# Out:
#    empid  poc  salary  name   area
# 0     10   10   10000  Sonu     up
# 1     20   20   19000  Monu  delhi
# 2     30   30   20000  Tonu     HP

# %% [markdown]
# **Operation:**
#
#     inplace: change inn existing
#
#     copy: return a new of

# %%
df1 = df.rename({'poc':'org'}, axis=1)
df1
# Out:
#    empid  org  salary  name   area
# 0     10   10   10000  Sonu     up
# 1     20   20   19000  Monu  delhi
# 2     30   30   20000  Tonu     HP

# %%
df
# Out:
#    empid  poc  salary  name   area
# 0     10   10   10000  Sonu     up
# 1     20   20   19000  Monu  delhi
# 2     30   30   20000  Tonu     HP

# %%
df.rename({'poc':'org'}, axis=1, inplace=True)
df
# Out:
#    empid  org  salary  name   area
# 0     10   10   10000  Sonu     up
# 1     20   20   19000  Monu  delhi
# 2     30   30   20000  Tonu     HP

# %%
df.rename({0: 11, 1:12, 2:'ducat'}, axis=0)
# Out:
#        empid  org  salary  name   area
# 11        10   10   10000  Sonu     up
# 12        20   20   19000  Monu  delhi
# ducat     30   30   20000  Tonu     HP

# %% [markdown]
# Change postion of column

# %%
df.reindex(["empid", 'area', 'name', 'salary'], axis=1)
# Out:
#    empid   area  name  salary
# 0     10     up  Sonu   10000
# 1     20  delhi  Monu   19000
# 2     30     HP  Tonu   20000

# %%
df.reindex([2,0,1], axis=0)
# Out:
#    empid  org  salary  name   area
# 2     30   30   20000  Tonu     HP
# 0     10   10   10000  Sonu     up
# 1     20   20   19000  Monu  delhi

# %% [markdown]
# **axis 0** means column
#
# **axis 1** means row

# %% [markdown]
# # Date Frame Operation:
#   >df.at[rowlabel,collabel]
#
#   >df.iat[rowpos,colpos]
#
# How to update an element:
# -------------------------
# >df.at[rowlabel,collabel]=value
#
# >df.iat[rowpos,colpos]=value
#
# How to select a column:
# --------------------
#    >df['col_label']
#
#    >df.col_label
#
# How to select multiple columns:
# ------------------------------
# df[['col_label1','col_label2']]
#
#
#
# DataFrame Slicing:
# ------------------
# >label slicing:
#     df.loc[row_label_slicing,col_label_slicing
#
# >pos slicing:
#     df.iloc[row_pos_slicing,col_pos_slicing]
#
# >boolean slicing:
#     df[condition]
#     df[(condition1) & (condition2)]
#     df[(condition1) | (condition2)]
#
# How to append a dataframe into exising dataframe:
# -------------------------------------------------
# >df3=df1.append(df2)
#
# >df3=df1.append(df2,ignoreIndex=True)
#
# How to convert type of a column:
# --------------------------------
# >df['col']=pd.to_type(df.col)
# >ex:
#    df['col']=pd.to_numeric(df.col)

# %%
weather_data = pd.read_csv('./Weather.csv')
weather_data
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26
# 1    1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05  25.95
# 2    1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63  26.34
# 3    1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73  25.84
# 4    1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47  26.29
# 5    1906  17.50  19.14  22.21  26.53  29.06  28.02  27.46  26.82  26.23
# 6    1907  19.27  19.42  22.03  26.98  27.52  27.66  27.28  26.38  26.26
# 7    1908  18.35  19.73  22.93  27.06  28.07  28.49  27.16  26.41  25.74
# 8    1909  17.79  19.05  23.40  25.76  27.97  27.67  26.56  26.43  25.47
# 9    1910  18.14  19.72  22.90  25.96  28.36  27.72  26.93  26.61  25.98
# 10   1911  18.52  19.18  22.05  26.00  28.55  28.02  27.44  27.04  26.22
# 11   1912  18.60  20.84  22.93  26.21  28.30  28.53  27.49  26.68  25.81
# 12   1913  18.20  19.98  22.15  26.61  27.95  27.91  27.00  26.80  26.02
# 13   1914  18.96  19.66  22.63  25.73  28.24  28.46  27.29  26.49  26.38
# 14   1915  17.93  19.00  22.69  26.23  29.17  28.58  27.77  27.32  26.82
# 15   1916  18.52  19.68  24.24  26.84  28.16  27.81  27.08  26.77  26.00
# 16   1917  18.16  19.94  22.46  25.29  26.97  27.41  27.15  26.64  25.79
# 17   1918  17.25  19.58  22.64  25.26  28.27  27.58  27.74  26.97  26.00
# 18   1919  18.78  19.15  23.15  26.19  28.20  28.30  27.28  26.84  25.84
# 19   1920  18.27  19.16  23.02  25.73  27.06  27.76  27.48  26.61  26.34
# 20   1921  18.61  22.12  24.26  27.11  30.78  28.04  27.40  26.59  25.92
# 21   1922  18.30  20.50  23.65  26.55  29.80  28.03  27.26  26.95  26.04
# 22   1923  18.23  19.35  23.21  26.81  28.33  28.95  26.89  26.71  25.89
# 23   1924  18.06  19.97  24.12  26.87  27.43  28.60  27.50  26.91  25.72
# 24   1925  17.53  19.08  23.50  27.24  27.82  27.76  27.01  26.64  26.29
# 25   1926  18.65  20.70  22.87  25.30  27.69  28.97  27.65  27.08  25.95
# 26   1927  18.15  19.40  22.71  26.13  27.70  27.93  27.23  26.66  26.10
# 27   1928  18.66  20.13  23.23  26.44  28.88  28.22  27.28  26.90  26.32
# 28   1929  18.25  19.00  24.05  26.44  28.58  28.07  27.26  26.64  26.41
# 29   1930  17.75  18.72  23.36  25.94  28.11  27.84  27.31  26.85  26.17
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 87   1988  18.58  20.83  23.51  26.60  28.60  28.37  27.12  26.91  26.48
# 88   1989  17.68  19.85  23.00  25.95  28.13  27.72  26.96  26.86  26.38
# 89   1990  18.56  20.33  22.79  26.15  27.71  28.11  27.06  26.99  26.55
# 90   1991  17.99  20.43  23.58  26.13  28.35  28.17  27.59  26.88  26.65
# 91   1992  18.36  19.77  22.95  26.21  27.75  28.40  27.31  26.78  26.11
# 92   1993  18.37  20.84  22.71  26.50  28.73  28.50  27.24  27.29  26.34
# 93   1994  19.33  20.20  24.14  26.04  28.72  28.56  27.34  27.01  26.31
# 94   1995  19.18  21.48  24.26  27.23  29.34  29.88  27.80  27.40  27.15
# 95   1996  19.81  21.73  25.13  26.67  28.37  28.08  27.42  26.77  26.64
# 96   1997  17.86  19.88  23.64  25.55  27.86  28.33  28.01  27.27  26.81
# 97   1998  18.84  20.60  22.98  27.00  29.18  28.88  27.78  27.42  26.70
# 98   1999  18.32  21.26  24.18  27.66  28.13  27.95  27.58  27.08  26.90
# 99   2000  18.87  19.78  23.22  27.27  28.92  28.02  27.34  26.98  26.53
# 100  2001  18.50  21.00  24.12  26.90  29.46  28.13  27.63  27.62  26.86
# 101  2002  18.78  20.52  24.44  27.66  29.56  28.77  28.47  27.27  26.43
# 102  2003  18.60  21.03  23.62  27.29  28.64  29.01  27.53  27.25  26.75
# 103  2004  18.83  21.03  26.19  27.38  28.12  27.94  27.44  27.16  26.80
# 104  2005  19.07  20.51  24.14  26.62  28.22  28.99  27.34  27.41  26.82
# 105  2006  19.96  23.02  23.91  26.83  28.82  28.13  27.92  27.15  26.42
# 106  2007  19.24  20.97  23.52  27.72  28.84  28.31  27.66  27.37  26.61
# 107  2008  18.49  19.83  24.43  26.54  28.42  28.10  27.50  27.00  26.44
# 108  2009  19.79  21.66  24.55  27.35  28.71  28.77  27.83  27.85  27.11
# 109  2010  19.15  21.23  26.53  28.40  29.19  28.51  27.55  27.33  26.60
# 110  2011  18.32  20.79  24.11  26.10  28.92  28.60  27.60  27.20  26.70
# 111  2012  18.25  20.43  23.98  26.89  28.72  28.91  27.98  27.31  26.65
# 112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22  26.87
# 113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42  26.61
# 114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64  27.04
# 115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17  27.72
# 116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12  28.11
#
#        OCT    NOV    DEC
# 0    25.08  21.73  18.95
# 1    24.37  21.33  18.78
# 2    24.57  20.96  18.29
# 3    24.36  21.07  18.84
# 4    26.16  22.07  18.71
# 5    24.75  21.93  19.55
# 6    24.72  22.11  18.46
# 7    24.25  21.06  18.15
# 8    24.37  22.01  18.86
# 9    24.04  20.72  18.05
# 10   24.57  21.10  18.76
# 11   24.44  21.00  18.44
# 12   24.35  20.92  18.70
# 13   23.97  21.87  18.73
# 14   25.46  22.18  18.31
# 15   24.60  21.03  18.17
# 16   23.85  20.80  18.39
# 17   24.54  21.71  18.37
# 18   24.36  21.48  18.58
# 19   24.85  21.84  18.78
# 20   23.84  21.10  19.24
# 21   23.94  21.28  18.39
# 22   23.89  21.23  19.08
# 23   24.50  21.04  18.97
# 24   24.61  21.29  18.63
# 25   24.41  20.59  18.80
# 26   24.70  21.16  19.41
# 27   24.92  21.77  18.73
# 28   24.12  21.71  18.44
# 29   24.60  21.41  19.11
# ..     ...    ...    ...
# 87   24.79  21.63  19.64
# 88   24.84  21.80  19.23
# 89   24.51  22.08  19.78
# 90   24.56  21.60  19.44
# 91   24.70  22.01  19.42
# 92   24.88  22.20  19.55
# 93   24.56  22.06  19.30
# 94   26.00  22.99  20.65
# 95   24.50  21.81  18.96
# 96   24.48  22.05  19.31
# 97   25.27  22.48  19.21
# 98   24.97  22.33  19.57
# 99   25.58  22.75  19.66
# 100  25.49  22.51  19.55
# 101  25.44  23.17  19.87
# 102  24.92  22.17  19.59
# 103  24.34  22.43  19.93
# 104  24.84  21.73  19.23
# 105  25.41  22.59  19.99
# 106  24.92  22.40  19.65
# 107  25.47  22.51  20.62
# 108  25.20  22.31  20.22
# 109  25.58  22.98  19.22
# 110  25.51  22.84  19.84
# 111  24.85  22.26  19.91
# 112  25.63  22.18  19.69
# 113  25.38  22.53  19.50
# 114  25.82  22.95  20.21
# 115  26.81  23.90  21.89
# 116  27.24  23.92  21.47
#
# [117 rows x 13 columns]

# %%
weather_data.set_index('YEAR', inplace=True)

# %%
weather_data
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26  25.08
# 1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05  25.95  24.37
# 1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63  26.34  24.57
# 1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73  25.84  24.36
# 1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47  26.29  26.16
# 1906  17.50  19.14  22.21  26.53  29.06  28.02  27.46  26.82  26.23  24.75
# 1907  19.27  19.42  22.03  26.98  27.52  27.66  27.28  26.38  26.26  24.72
# 1908  18.35  19.73  22.93  27.06  28.07  28.49  27.16  26.41  25.74  24.25
# 1909  17.79  19.05  23.40  25.76  27.97  27.67  26.56  26.43  25.47  24.37
# 1910  18.14  19.72  22.90  25.96  28.36  27.72  26.93  26.61  25.98  24.04
# 1911  18.52  19.18  22.05  26.00  28.55  28.02  27.44  27.04  26.22  24.57
# 1912  18.60  20.84  22.93  26.21  28.30  28.53  27.49  26.68  25.81  24.44
# 1913  18.20  19.98  22.15  26.61  27.95  27.91  27.00  26.80  26.02  24.35
# 1914  18.96  19.66  22.63  25.73  28.24  28.46  27.29  26.49  26.38  23.97
# 1915  17.93  19.00  22.69  26.23  29.17  28.58  27.77  27.32  26.82  25.46
# 1916  18.52  19.68  24.24  26.84  28.16  27.81  27.08  26.77  26.00  24.60
# 1917  18.16  19.94  22.46  25.29  26.97  27.41  27.15  26.64  25.79  23.85
# 1918  17.25  19.58  22.64  25.26  28.27  27.58  27.74  26.97  26.00  24.54
# 1919  18.78  19.15  23.15  26.19  28.20  28.30  27.28  26.84  25.84  24.36
# 1920  18.27  19.16  23.02  25.73  27.06  27.76  27.48  26.61  26.34  24.85
# 1921  18.61  22.12  24.26  27.11  30.78  28.04  27.40  26.59  25.92  23.84
# 1922  18.30  20.50  23.65  26.55  29.80  28.03  27.26  26.95  26.04  23.94
# 1923  18.23  19.35  23.21  26.81  28.33  28.95  26.89  26.71  25.89  23.89
# 1924  18.06  19.97  24.12  26.87  27.43  28.60  27.50  26.91  25.72  24.50
# 1925  17.53  19.08  23.50  27.24  27.82  27.76  27.01  26.64  26.29  24.61
# 1926  18.65  20.70  22.87  25.30  27.69  28.97  27.65  27.08  25.95  24.41
# 1927  18.15  19.40  22.71  26.13  27.70  27.93  27.23  26.66  26.10  24.70
# 1928  18.66  20.13  23.23  26.44  28.88  28.22  27.28  26.90  26.32  24.92
# 1929  18.25  19.00  24.05  26.44  28.58  28.07  27.26  26.64  26.41  24.12
# 1930  17.75  18.72  23.36  25.94  28.11  27.84  27.31  26.85  26.17  24.60
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1988  18.58  20.83  23.51  26.60  28.60  28.37  27.12  26.91  26.48  24.79
# 1989  17.68  19.85  23.00  25.95  28.13  27.72  26.96  26.86  26.38  24.84
# 1990  18.56  20.33  22.79  26.15  27.71  28.11  27.06  26.99  26.55  24.51
# 1991  17.99  20.43  23.58  26.13  28.35  28.17  27.59  26.88  26.65  24.56
# 1992  18.36  19.77  22.95  26.21  27.75  28.40  27.31  26.78  26.11  24.70
# 1993  18.37  20.84  22.71  26.50  28.73  28.50  27.24  27.29  26.34  24.88
# 1994  19.33  20.20  24.14  26.04  28.72  28.56  27.34  27.01  26.31  24.56
# 1995  19.18  21.48  24.26  27.23  29.34  29.88  27.80  27.40  27.15  26.00
# 1996  19.81  21.73  25.13  26.67  28.37  28.08  27.42  26.77  26.64  24.50
# 1997  17.86  19.88  23.64  25.55  27.86  28.33  28.01  27.27  26.81  24.48
# 1998  18.84  20.60  22.98  27.00  29.18  28.88  27.78  27.42  26.70  25.27
# 1999  18.32  21.26  24.18  27.66  28.13  27.95  27.58  27.08  26.90  24.97
# 2000  18.87  19.78  23.22  27.27  28.92  28.02  27.34  26.98  26.53  25.58
# 2001  18.50  21.00  24.12  26.90  29.46  28.13  27.63  27.62  26.86  25.49
# 2002  18.78  20.52  24.44  27.66  29.56  28.77  28.47  27.27  26.43  25.44
# 2003  18.60  21.03  23.62  27.29  28.64  29.01  27.53  27.25  26.75  24.92
# 2004  18.83  21.03  26.19  27.38  28.12  27.94  27.44  27.16  26.80  24.34
# 2005  19.07  20.51  24.14  26.62  28.22  28.99  27.34  27.41  26.82  24.84
# 2006  19.96  23.02  23.91  26.83  28.82  28.13  27.92  27.15  26.42  25.41
# 2007  19.24  20.97  23.52  27.72  28.84  28.31  27.66  27.37  26.61  24.92
# 2008  18.49  19.83  24.43  26.54  28.42  28.10  27.50  27.00  26.44  25.47
# 2009  19.79  21.66  24.55  27.35  28.71  28.77  27.83  27.85  27.11  25.20
# 2010  19.15  21.23  26.53  28.40  29.19  28.51  27.55  27.33  26.60  25.58
# 2011  18.32  20.79  24.11  26.10  28.92  28.60  27.60  27.20  26.70  25.51
# 2012  18.25  20.43  23.98  26.89  28.72  28.91  27.98  27.31  26.65  24.85
# 2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22  26.87  25.63
# 2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42  26.61  25.38
# 2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64  27.04  25.82
# 2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17  27.72  26.81
# 2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12  28.11  27.24
#
#         NOV    DEC
# YEAR
# 1901  21.73  18.95
# 1902  21.33  18.78
# 1903  20.96  18.29
# 1904  21.07  18.84
# 1905  22.07  18.71
# 1906  21.93  19.55
# 1907  22.11  18.46
# 1908  21.06  18.15
# 1909  22.01  18.86
# 1910  20.72  18.05
# 1911  21.10  18.76
# 1912  21.00  18.44
# 1913  20.92  18.70
# 1914  21.87  18.73
# 1915  22.18  18.31
# 1916  21.03  18.17
# 1917  20.80  18.39
# 1918  21.71  18.37
# 1919  21.48  18.58
# 1920  21.84  18.78
# 1921  21.10  19.24
# 1922  21.28  18.39
# 1923  21.23  19.08
# 1924  21.04  18.97
# 1925  21.29  18.63
# 1926  20.59  18.80
# 1927  21.16  19.41
# 1928  21.77  18.73
# 1929  21.71  18.44
# 1930  21.41  19.11
# ...     ...    ...
# 1988  21.63  19.64
# 1989  21.80  19.23
# 1990  22.08  19.78
# 1991  21.60  19.44
# 1992  22.01  19.42
# 1993  22.20  19.55
# 1994  22.06  19.30
# 1995  22.99  20.65
# 1996  21.81  18.96
# 1997  22.05  19.31
# 1998  22.48  19.21
# 1999  22.33  19.57
# 2000  22.75  19.66
# 2001  22.51  19.55
# 2002  23.17  19.87
# 2003  22.17  19.59
# 2004  22.43  19.93
# 2005  21.73  19.23
# 2006  22.59  19.99
# 2007  22.40  19.65
# 2008  22.51  20.62
# 2009  22.31  20.22
# 2010  22.98  19.22
# 2011  22.84  19.84
# 2012  22.26  19.91
# 2013  22.18  19.69
# 2014  22.53  19.50
# 2015  22.95  20.21
# 2016  23.90  21.89
# 2017  23.92  21.47
#
# [117 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
weather_data.plot()
