# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x= np.linspace(0, 5, 11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x ** 2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, x)

# %%
plt.plot(x,y)

# %%
plt.plot(y,y)

# %%
plt.plot(x,y, 'r')
plt.xlabel('X label')
plt.ylabel("Y label")
plt.title("Plot Title")
# Out:
# Text(0.5, 1.0, 'Plot Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y)

plt.subplot(1,2,2)
plt.plot(y,x, '-r')

# %%
fig = plt.figure()
axis = fig.add_axes([0.1,0.1,0.8,0.8])

# %%
fig = plt.figure()
axis = fig.add_axes([0.1,0.1,0.8,0.8])
axis.plot(x,y)

# %%
fig = plt.figure()
axis = fig.add_axes([0.1,0.1,0.8,0.8])
axis.plot(x,y)
axis.set_xlabel('X label')
axis.set_ylabel('Y label')
axis.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1,0.1,0.8,0.8])
axis2 = fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1,0.1,0.8,0.8])
axis2 = fig.add_axes([0.2,0.15,0.4,0.3])

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1,0.1,0.8,0.8])
axis2 = fig.add_axes([0.2,0.5,0.4,0.3])
axis1.plot(x,y)
axis1.set_title('Larger Plot')
axis2.plot(y,x)
axis2.set_title('Smaller Plot')
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axis1.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2, ncols=3)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f88a2198d30>,
# ...
#       dtype=object)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)
for current_axis in axes:
    current_axis.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y)
axes[0].set_title('First Plot')
axes[1].plot(x,y, '-r')
axes[1].set_title('2nd Plot')
plt.tight_layout()

# %%
fig  =plt.figure(figsize=(3,2), dpi=100)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig  =plt.figure(figsize=(8,2), dpi=100)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig, ax  =plt.subplots(nrows=2, ncols=1, figsize=(8,2), dpi=200)
ax[0].plot(x,y)
ax[1].plot(y,x)
plt.tight_layout()

# %%
fig

# %%
fig.savefig('my_picture.png', dpi=600)

# %%
fig  =plt.figure(figsize=(3,2), dpi=300)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y**2, label='X Square')
ax.plot(x,y**3, 'r', label='X cubed')
ax.legend(loc=(0.1, 0.1))

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='orange')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', linewidth=3)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', linewidth=3, alpha=0.5)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', linewidth=3, linestyle='--')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', lw=3, linestyle='steps')
# Out:
# /home/chandan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', linewidth=3, ls=':')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', linewidth=3, linestyle='-', marker='o')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', linewidth=3, linestyle='-', marker='o', markersize=10)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', linewidth=3, linestyle='-', marker='2', markersize=10)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', linewidth=3, linestyle='-', marker='o', markersize=10, markerfacecolor='yellow')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', linewidth=3, linestyle='-', marker='o', markersize=10, markerfacecolor='yellow',
       markeredgecolor='green'
       )
